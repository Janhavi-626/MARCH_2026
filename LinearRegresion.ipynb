# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df1=sns.load_dataset("titanic")
df2=sns.load_dataset("tips")

# %%
df1=df1[['fare','age','sibsp','parch']]
y=df1['fare']
x=df1.drop('fare',axis=1)

# %%
df2=df2[['tip','total_bill','size']]
y=df2['tip']
x=df2.drop('tip',axis=1)

# %%
df1.isna().sum()
# Out:
# fare       0
# age      177
# sibsp      0
# parch      0
# dtype: int64

# %%
df1['age'] = df1['age'].fillna(df1['age'].median())

# %%
df1.isna().sum()
# Out:
# fare     0
# age      0
# sibsp    0
# parch    0
# dtype: int64

# %%
df1=df1[['fare','age','sibsp','parch']]
y=df1['fare']
x=df1.drop('fare',axis=1)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (712, 3) (179, 3) (712,) (179,)

# %%
df1.shape
# Out:
# (891, 4)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
predicted_values=model.predict(x_test)
actual_values=y_test.values
mae=sum(abs(actual_values-predicted_values))/(x_test.shape[0])
from sklearn.metrics import mean_absolute_error
mean_absolute_error(actual_values,predicted_values)
# Out:
# 23.990565316737303

# %%
mae
# Out:
# np.float64(23.990565316737303)

# %%
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
predicted_values=model.predict(x_test)
actual_values=y_test.values
mae=sum(abs(actual_values-predicted_values))/(x_test.shape[0])
from sklearn.metrics import mean_absolute_error
mean_absolute_error(actual_values,predicted_values)
# Out:
# 27.928401663284536

# %%
model=RandomForestRegressor()
model.fit(x_train,y_train)
predicted_values=model.predict(x_test)
actual_values=y_test.values
mae=sum(abs(actual_values-predicted_values))/(x_test.shape[0])
from sklearn.metrics import mean_absolute_error
mean_absolute_error(actual_values,predicted_values)
# Out:
# 25.507421655570464

# %%
from sklearn.metrics import mean_absolute_error
def model_prediction(algoname,x_train,y_train,x_test,y_test):
    model=algoname
    model.fit(x_train,y_train)
    predicted_values=model.predict(x_test)
    actual_values=y_test.values
    mae=sum(abs(actual_values-predicted_values))/(x_test.shape[0])
    return  mean_absolute_error(actual_values,predicted_values)

# %%
model_prediction(DecisionTreeRegressor(),x_train,y_train,x_test,y_test)
# Out:
# 26.828401663284534

# %%
model_prediction(RandomForestRegressor(),x_train,y_train,x_test,y_test)
# Out:
# 25.271907095448988

# %%
model_prediction(LinearRegression(),x_train,y_train,x_test,y_test)
# Out:
# 23.990565316737303

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_absolute_percentage_error

# %%
predicted_values=model.predict(x_test)
actual_values=y_test.values

# %%
mae=mean_absolute_error(actual_values,predicted_values)
mse=mean_squared_error(actual_values,predicted_values)
rmse=np.sqrt(mse)
mape=((actual_values-predicted_values)/actual_values).sum()/x_test.shape[0]
print(mae,mse,rmse,mape)
# Out:
# 25.507421655570464 1925.9311390919474 43.885431968843 -inf
# C:\Users\User\AppData\Local\Temp\ipykernel_10328\3356387526.py:4: RuntimeWarning: divide by zero encountered in divide
#   mape=((actual_values-predicted_values)/actual_values).sum()/x_test.shape[0]

# %%
actual_values[actual_values>0].shape
# Out:
# (177,)

# %%
predicted_values.shape
# Out:
# (179,)

# %%
from sklearn.metrics import mean_absolute_error
def model_prediction(algoname,x_train,y_train,x_test,y_test):
    model=algoname
    model.fit(x_train,y_train)
    predicted_values=model.predict(x_test)
    actual_values=y_test.values
    mae=sum(abs(actual_values-predicted_values))/(x_test.shape[0])
    mae=mean_absolute_error(actual_values,predicted_values)
    mse=mean_squared_error(actual_values,predicted_values)
    rmse=np.sqrt(mse)
    mape=((actual_values-predicted_values)/actual_values).sum()/x_test.shape[0]
    return [mae,mse,rmse,mape]

# %%
model_prediction(DecisionTreeRegressor(),x_train,y_train,x_test,y_test)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10328\3602218722.py:11: RuntimeWarning: divide by zero encountered in divide
#   mape=((actual_values-predicted_values)/actual_values).sum()/x_test.shape[0]
# [27.901027361608556,
#  2484.8064364310685,
#  np.float64(49.847832815791186),
#  np.float64(-inf)]

# %%
model_prediction(RandomForestRegressor(),x_train,y_train,x_test,y_test)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10328\3602218722.py:11: RuntimeWarning: divide by zero encountered in divide
#   mape=((actual_values-predicted_values)/actual_values).sum()/x_test.shape[0]
# [25.055320918855617,
#  1836.0579561408586,
#  np.float64(42.84924685616841),
#  np.float64(-inf)]

# %%
model_prediction(LinearRegression(),x_train,y_train,x_test,y_test)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10328\3602218722.py:11: RuntimeWarning: divide by zero encountered in divide
#   mape=((actual_values-predicted_values)/actual_values).sum()/x_test.shape[0]
# [23.990565316737303,
#  1432.8757467372736,
#  np.float64(37.85334525160588),
#  np.float64(-inf)]

# %%
import joblib
joblib.dump(model,"linear_regression_model.pkl")
# Out:
# ['linear_regression_model.pkl']

# %%
import pickle
with open("linear_regression_model.pkl",'wb') as f:
  pickle.dump(model,f)

# %%
model_prediction(DecisionTreeRegressor(),x_train,y_train,x_test,y_test)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10328\3602218722.py:11: RuntimeWarning: divide by zero encountered in divide
#   mape=((actual_values-predicted_values)/actual_values).sum()/x_test.shape[0]
# [27.901027361608556,
#  2491.5157877594484,
#  np.float64(49.91508577333558),
#  np.float64(-inf)]

# %%
model_prediction(DecisionTreeRegressor(),x_train,y_train,x_train,y_train)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10328\3602218722.py:11: RuntimeWarning: divide by zero encountered in divide
#   mape=((actual_values-predicted_values)/actual_values).sum()/x_test.shape[0]
# C:\Users\User\AppData\Local\Temp\ipykernel_10328\3602218722.py:11: RuntimeWarning: invalid value encountered in divide
#   mape=((actual_values-predicted_values)/actual_values).sum()/x_test.shape[0]
# [14.589978012703899,
#  1173.3195851950811,
#  np.float64(34.25375286293578),
#  np.float64(nan)]

# %% [markdown]
# For Tips dataset

# %%
df2=df2[['tip','total_bill','size']]
y=df2['tip']
x=df2.drop('tip',axis=1)

# %%
df1.isna().sum()
# Out:
# fare     0
# age      0
# sibsp    0
# parch    0
# dtype: int64

# %%
df1.isna().sum()
# Out:
# fare     0
# age      0
# sibsp    0
# parch    0
# dtype: int64

# %%
df2=df2[['tip','total_bill','size']]
y=df2['tip']
x=df2.drop('tip',axis=1)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (195, 2) (49, 2) (195,) (49,)

# %%
df1.shape
# Out:
# (891, 4)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
predicted_values=model.predict(x_test)
actual_values=y_test.values
mae=sum(abs(actual_values-predicted_values))/(x_test.shape[0])
from sklearn.metrics import mean_absolute_error
mean_absolute_error(actual_values,predicted_values)
# Out:
# 0.6639235737596483

# %%
mae
# Out:
# np.float64(0.6639235737596484)

# %%
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
predicted_values=model.predict(x_test)
actual_values=y_test.values
mae=sum(abs(actual_values-predicted_values))/(x_test.shape[0])
from sklearn.metrics import mean_absolute_error
mean_absolute_error(actual_values,predicted_values)
# Out:
# 0.8271428571428572

# %%
model=RandomForestRegressor()
model.fit(x_train,y_train)
predicted_values=model.predict(x_test)
actual_values=y_test.values
mae=sum(abs(actual_values-predicted_values))/(x_test.shape[0])
from sklearn.metrics import mean_absolute_error
mean_absolute_error(actual_values,predicted_values)
# Out:
# 0.7198367346938773

# %%
from sklearn.metrics import mean_absolute_error
def model_prediction(algoname,x_train,y_train,x_test,y_test):
    model=algoname
    model.fit(x_train,y_train)
    predicted_values=model.predict(x_test)
    actual_values=y_test.values
    mae=sum(abs(actual_values-predicted_values))/(x_test.shape[0])
    return  mean_absolute_error(actual_values,predicted_values)

# %%
model_prediction(DecisionTreeRegressor(),x_train,y_train,x_test,y_test)
# Out:
# 0.8628571428571429

# %%
model_prediction(RandomForestRegressor(),x_train,y_train,x_test,y_test)
# Out:
# 0.7268414965986396

# %%
model_prediction(LinearRegression(),x_train,y_train,x_test,y_test)
# Out:
# 0.6639235737596483

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_absolute_percentage_error

# %%
predicted_values=model.predict(x_test)
actual_values=y_test.values

# %%
mae=mean_absolute_error(actual_values,predicted_values)
mse=mean_squared_error(actual_values,predicted_values)
rmse=np.sqrt(mse)
mape=((actual_values-predicted_values)/actual_values).sum()/x_test.shape[0]
print(mae,mse,rmse,mape)
# Out:
# 0.7198367346938773 0.7851341073469396 0.8860779352556634 -0.1780083650942611

# %%
actual_values[actual_values>0].shape
# Out:
# (49,)

# %%
predicted_values.shape
# Out:
# (49,)

# %%
from sklearn.metrics import mean_absolute_error
def model_prediction(algoname,x_train,y_train,x_test,y_test):
    model=algoname
    model.fit(x_train,y_train)
    predicted_values=model.predict(x_test)
    actual_values=y_test.values
    mae=sum(abs(actual_values-predicted_values))/(x_test.shape[0])
    mae=mean_absolute_error(actual_values,predicted_values)
    mse=mean_squared_error(actual_values,predicted_values)
    rmse=np.sqrt(mse)
    mape=((actual_values-predicted_values)/actual_values).sum()/x_test.shape[0]
    return [mae,mse,rmse,mape]

# %%
model_prediction(DecisionTreeRegressor(),x_train,y_train,x_test,y_test)
# Out:
# [0.866326530612245,
#  1.1041816326530614,
#  np.float64(1.0508004723319557),
#  np.float64(-0.1852686277882289)]

# %%
model_prediction(RandomForestRegressor(),x_train,y_train,x_test,y_test)
# Out:
# [0.7260755102040817,
#  0.7986766451020418,
#  np.float64(0.8936871069351072),
#  np.float64(-0.18021835890840235)]

# %%
model_prediction(LinearRegression(),x_train,y_train,x_test,y_test)
# Out:
# [0.6639235737596483,
#  0.6485996190543518,
#  np.float64(0.8053568271607013),
#  np.float64(-0.16635193181118937)]

# %%
import joblib
joblib.dump(model,"DecisionTreeRegressor_model.pkl")
# Out:
# ['DecisionTreeRegressor_model.pkl']

# %%
import pickle
with open("DecisionTreeRegressor_model.pkl",'wb') as f:
  pickle.dump(model,f)

# %%
model_prediction(DecisionTreeRegressor(),x_train,y_train,x_test,y_test)
# Out:
# [0.8212244897959182,
#  1.0119673469387755,
#  np.float64(1.0059658776214904),
#  np.float64(-0.16172320962096196)]

# %%
model_prediction(DecisionTreeRegressor(),x_train,y_train,x_train,y_train)
# Out:
# [0.017777777777777778,
#  0.01429059829059829,
#  np.float64(0.11954329044575564),
#  np.float64(-0.0022801283488884582)]
