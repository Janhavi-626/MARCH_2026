# %%
print("hello")
# Out:
# hello

# %%
a=20
b=10
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a**b)
print(a%b)
# Out:
# 30
# 10
# 200
# 2.0
# 2
# 10240000000000
# 0

# %%
New_studentbatch1=120
total_students=1800
total_students=total_students+New_studentbatch1
print(f"Total students after adding batch 1 students:{total_students}")
# Out:
# Total students after adding batch 1 students:1920

# %%
ds_modules=15
de_modules=18
total_modules=(ds_modules+de_modules)
print(f"Total modules in DS and DE :{total_modules}")
# Out:
# Total modules in DS and DE :33

# %%
batch_size_1 = 50
batch_size_2 = 45
combined_batch_size = batch_size_1 + batch_size_2
print(f"3. Combined size of two batches: {combined_batch_size}")
# Out:
# 3. Combined size of two batches: 95

# %% [markdown]
#  5. Adding a negative number (subtraction)

# %%
active_students = 1620
dropouts = -20 # Representing dropouts as negative addition
active_students = active_students + dropouts
print(f"Active students after dropouts:{active_students}")
# Out:
# Active students after dropouts:1600

# %%
# 6. Incrementing a counter
completed_projects = 5
completed_projects = completed_projects + 1
print(f"6. Completed projects incremented: {completed_projects}")
# Out:
# 6. Completed projects incremented: 6

# %%
# 10. Combining positive and negative changes
student_change = 50 + (-10) + 30
print(f"10. Net student change: {student_change}")
# Out:
# 10. Net student change: 70

# %% [markdown]
# SUBSTRACTION

# %%
batch_capacity=60
enrolled=55
remaining_seats=batch_capacity-enrolled
print(f"Remaining Sats:{remaining_seats}")
# Out:
# Remaining Sats:5

# %%
initial_students=1500
final_students=1400
dropouts=initial_students-final_students
print(f"Number of dropouts:{dropouts}")
# Out:
# Number of dropouts:100

# %%
#Finding the difference in module counts
ds_modules=15
de_modules=20
module_difference=de_modules-ds_modules
print(f"Difference in modules:{module_difference}")
# Out:
# Difference in modules:5

# %%
#Substacting Zero
revenue=60000
revenue_after_discount=revenue-0
print(f"profit:{revenue_after_discount}")
# Out:
# profit:60000

# %%
#Resulting in negative number
costs=600000
profit=revenue-costs
print(f"Profit:{profit}")
# Out:
# Profit:-540000

# %%
#Decrementing a counter
live_session_left=10
live_session_left=live_session_left-1
print(f"live session left after one:{live_session_left}")
# Out:
# live session left after one:9

# %% [markdown]
# Multiplication

# %%
total_students=1000
course_fee=500
total_revenue=total_students*course_fee
print(f"Total potential revenue:{total_revenue}")
# Out:
# Total potential revenue:500000

# %%
api_calls=10000
cost_per_call=2
total_api_cost=api_calls*cost_per_call
print(total_api_cost)
# Out:
# 20000

# %% [markdown]
# Floor Division

# %%
# 1. Calculating number of full batches
total_students=157
student_per_batch=50
full_batches=total_students//student_per_batch
print(f"Number of full batches:{full_batches}")
# Out:
# Number of full batches:3

# %% [markdown]
# Modullo(%)

# %%
total_students = 157
students_per_batch = 50
remaining_students = total_students % students_per_batch
print(f"1. Students for the last (incomplete) batch: {remaining_students}")
# Out:
# 1. Students for the last (incomplete) batch: 7

# %% [markdown]
#  Exponentiation (**)

# %%
initial_students = 100
growth_factor = 2
periods = 3
projected_students = initial_students * (growth_factor ** periods)
projected_students
# Out:
# 800

# %%
# 2. Calculating squares (power of 2)
side_length = 5
area = side_length ** 2
print(f"2. Area of square: {area}")
# Out:
# 2. Area of square: 25

# %%
# 3. Calculating cubes (power of 3)
edge_length = 3
volume = edge_length ** 3
print(f"Volume of cube:{volume}")
# Out:
# Volume of cube:27

# %%
##Absolute(abs)
student_change = -50
abs_change = abs(student_change)
print(f"1. Absolute student change: {abs_change}")
# Out:
# 1. Absolute student change: 50

# %%
# 2. Absolute value of a positive number
positive_count = 1500
abs_count = abs(positive_count)
print(f"2. Absolute value of 1500: {abs_count}")
# Out:
# 2. Absolute value of 1500: 1500

# %%
# 3. Absolute value of zero
zero_value = 0
abs_zero = abs(zero_value)
print(f"3. Absolute value of 0: {abs_zero}")
# Out:
# 3. Absolute value of 0: 0

# %%
# 4. Ensuring a difference is positive
score1 = 85
score2 = 92
score_diff = abs(score1 - score2)
print(f"4. Absolute difference between scores: {score_diff}")
# Out:
# 4. Absolute difference between scores: 7

# %%
# 6. Using abs() in calculations
value = -10
result = abs(value) * 5
print(f"6. Calculation with abs(): {result}")
# Out:
# 6. Calculation with abs(): 50

# %%
# 7. Absolute value from a calculation result
net_profit = 10000 - 15000
abs_profit_or_loss = abs(net_profit)
print(f"7. Magnitude of profit/loss: {abs_profit_or_loss}")
# Out:
# 7. Magnitude of profit/loss: 5000

# %%
# 8. Applying to batch id difference
batch_id1 = 101
batch_id2 = 105
id_distance = abs(batch_id1 - batch_id2)
print(f"8. Distance between batch IDs: {id_distance}")
# Out:
# 8. Distance between batch IDs: 4

# %%
#pow(base, exp[, mod])
# 1. Simple power calculation
result = pow(10, 3)
print(f"1. pow(10, 3):{result}")
# Out:
# 1. pow(10, 3):1000

# %%
# 2. Equivalent to growth example above
initial_students = 100
growth_factor = 2
periods = 3
projected_students = initial_students * pow(growth_factor, periods)
print(f"2. Projected students using pow(): {projected_students}")
# Out:
# 2. Projected students using pow(): 800

# %%
#divmod(a, b)
# 1. Getting full batches and remaining students simultaneously
total_students = 157
students_per_batch = 50
batches, remaining = divmod(total_students, students_per_batch)
print(f"1. Batches: {batches}, Remaining Students: {remaining}")
# Out:
# 1. Batches: 3, Remaining Students: 7
