# %% [markdown]
# A dictionary is a collection data type in Python that stores data in key-value pairs. Think of it like a real dictionary where you look up a word (key) to find its meaning (value).
#
# set = {value1, value2, value3}
#
# dict = {key:value, key:value, key:value}
#
# dict = {name: phoneNumber, lohit: 812123164 }

# %%
## Chars of dicstionary

# 1. key-value paris

# Every item in a dict consists of two parts:
#  A key(identifier)
# A value (Data associated with that key)
student={
    "name":"Janhavi",
    "age":"23",
    "grade":"A+"
}

# %%
student
# Out:
# {'name': 'Janhavi', 'age': '23', 'grade': 'A+'}

# %%
type(student)
# Out:
# dict

# %%
## 2. Keys must be unique
student={
    "name":"Archana",
    "age":"24",
    "name":"Boomika"    #This overrides the first "name"
}

# %%
student
# Out:
# {'name': 'Boomika', 'age': '24'}

# %%
## Keys must be Immutable

# can be = string, numbers, tuples.
# cannot be = lists, sets, dict


# validkeys
valid_keys={
    "name":"Roopa",
    42:"Answer",
    (1,2):"Tuple",
    True:"Boolean"
}

# %%
valid_keys
# Out:
# {'name': 'Roopa', 42: 'Answer', (1, 2): 'Tuple', True: 'Boolean'}

# %%
#Invalid keys
invalid_keys={[1,2]:"List1"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 #Invalid keys
# ----> 2 invalid_keys={[1,2]:"List1"}
#
# TypeError: unhashable type: 'list'

# %%
## Values can be anythin
##sting, numbers, list, set, other dicts..
valid_dict={
    "name":["Jaanu"],
    42:("Answer"),
    (1,2):{"Tuple"},
    True:"Boolean"
}

# %%
## Mutable (changeable)
# Creating dict
empty_dict={}
my_dictionary={1:"value","value":1}

# %%
empty_dict
# Out:
# {}

# %%
my_dictionary
# Out:
# {1: 'value', 'value': 1}

# %%
## using constructor
person = dict(name = "Alice", age = 25, city = "Mumbai")
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Mumbai'}

# %%
type(person)
# Out:
# dict

# %%
## from a list of tuple
pairs=[("name","someone"),("age",34),("city","mumbai")]
type(pairs)
# Out:
# list

# %%
person1=dict(pairs)
person1
# Out:
# {'name': 'someone', 'age': 34, 'city': 'mumbai'}

# %%
type(person1)
# Out:
# dict

# %%
## using fromkey() - Same value for mutliple keys
keys = ["name", "age","city"]
default_values=dict.fromkeys(keys,"unknown")
default_values
# Out:
# {'name': 'unknown', 'age': 'unknown', 'city': 'unknown'}

# %%
type(default_values)
# Out:
# dict

# %%
## Accessing Dictionary Items
person = {'name': 'Alice', 'age': 34, 'city': 'mumbai'}
person["name"]
# Out:
# 'Alice'

# %%
person["age"]
# Out:
# 34

# %%
person["city"]
# Out:
# 'mumbai'

# %%
person["address"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 person["address"]
#
# KeyError: 'address'

# %%
#because address is not present in the dictionary

# %%
## Using get() method (safer)
person
# Out:
# {'name': 'Alice', 'age': 34, 'city': 'mumbai'}

# %%
person.get("name")
# Out:
# 'Alice'

# %%
person.get("age")
# Out:
# 34

# %%
person.get("city")
# Out:
# 'mumbai'

# %%
person.get("address")   ##this means none

# %%
## Provide a default value

person.get("Address", "returns given default value")
# Out:
# 'returns given default value'

# %%
## Accessing Nested Dictionareis
student = {
    "name": "Alice",
    "age": 25,
    "address": {
        "city": "Mumbai",
        "pincode": 400001
    }
}

# %%
student
# Out:
# {'name': 'Alice', 'age': 25, 'address': {'city': 'Mumbai', 'pincode': 400001}}

# %%
student["address"]["city"]
# Out:
# 'Mumbai'

# %%
student["address"]["pincode"]
# Out:
# 400001

# %%
## Adding and modifying items

# Adding new Items
person = {"name": "Alice","age": 25}

# %%
person["city"]="mumbai"
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'mumbai'}

# %%
person["phone"]=8088227866

# %%
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'mumbai', 'phone': 8088227866}

# %%
# Modify Existing Items
person['age']
# Out:
# 25

# %%
person["age"]=37

# %%
person
# Out:
# {'name': 'Alice', 'age': 37, 'city': 'mumbai', 'phone': 8088227866}

# %%
person["city"]="Banglore"

# %%
person
# Out:
# {'name': 'Alice', 'age': 37, 'city': 'Banglore', 'phone': 8088227866}

# %%
## Using update() - Add/ Modify multiple items..

person = {"name": "Alice","age": 25,}

# addding multiple items..

person.update({"city": "Mumbai", "phone": 12948291847})

# %%
person.update({"city":"mumbai","phone":8088227866})

# %%
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'mumbai', 'phone': 8088227866}

# %%
## removing items
# method 1 usign del keyword

person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'mumbai', 'phone': 8088227866}

# %%
del person["age"]

# %%
person
# Out:
# {'name': 'Alice', 'city': 'mumbai', 'phone': 8088227866}

# %%
del person["phone"]

# %%
person
# Out:
# {'name': 'Alice', 'city': 'mumbai'}

# %%
# using pop(): Return removed values
## Remove and return value
person = {'name': 'Amit', 'age': 35, 'city': 'Mumbai', 'phone': 12948291847}

# %%
age=person.pop('age')
age
# Out:
# 35

# %%
person
# Out:
# {'name': 'Amit', 'city': 'Mumbai', 'phone': 12948291847}

# %%
## with defaul value (if key doesn't exist)
phone = person.pop("phone")

# %%
phone
# Out:
# 12948291847

# %%
person
# Out:
# {'name': 'Amit', 'city': 'Mumbai'}

# %%
phone_removed=person.pop("phone","Not Found")
phone_removed
# Out:
# 'Not Found'

# %%
## using pipitem() - Remove Last Item

person = {'name': 'Amit', 'age': 35, 'city': 'Mumbai', 'phone': 12948291847}


item = person.popitem()

# %%
item
# Out:
# ('phone', 12948291847)

# %%
type(item)
# Out:
# tuple

# %%
item1 = person.popitem()
item1
# Out:
# ('age', 35)

# %%
type(item1)
# Out:
# tuple

# %%
empty = {}
item4 = empty.popitem()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[108], line 2
#       1 empty = {}
# ----> 2 item4 = empty.popitem()
#
# KeyError: 'popitem(): dictionary is empty'

# %%
person = {'name': 'Amit', 'age': 35, 'city': 'Mumbai', 'phone': 12948291847}
print(person)
person.clear()

person
# Out:
# {'name': 'Amit', 'age': 35, 'city': 'Mumbai', 'phone': 12948291847}
# {}

# %%
# if.. if,else.. if elif else..


# for loop,

# %%
# for loop
# A for loop in Python is used to iterate (loop) over a sequence like:

# lists strings tuples dictionaries ranges

# It lets you execute a block of code multiple times automatically.

# %%
## print hello for 10 times.....

print("hello")
print("hello")
print("hello")
print("hello")
print("hello")
print("hello")
print("hello")
print("hello")
print("hello")
print("hello")
print("hello")
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
for i in range(20):
 print("hello")
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %% [markdown]
# basic syntax for loop:

# %% [markdown]
# for variable in sequence:
#
# code block you want to execute
#
# variable = temperory variable which you have for each loop..
#
# sequence : lists,strings,tuples dictionaries, ranges
#
# int = 19 float = 1.5 boolean = True, False..
#
# sequencial = string -- "hello" list = [1,2,3,4,5] tuple = (11,3,,,4,5,_) dict = {key:value, key:value, key:value}

# %%
## basic syntax for loop:

#for variable in sequence:
   # code block you want to execute

# %%
# list of fruits print them all

fruits = ["apple", "banana", "cherry","apple", "banana", "cherry"]


## books : for book in books:

## cars = for car in cars:

# chunks = for chunk in chunk

# %%
len(fruits)
# Out:
# 6

# %%
for fruit in fruits:
    print(f"This is my favorite fruit from fruits:{fruit.upper()}")
# Out:
# This is my favorite fruit from fruits:APPLE
# This is my favorite fruit from fruits:BANANA
# This is my favorite fruit from fruits:CHERRY
# This is my favorite fruit from fruits:APPLE
# This is my favorite fruit from fruits:BANANA
# This is my favorite fruit from fruits:CHERRY

# %%
cars=("honda", "tesla", "tata")
for car in cars:
    print(f"My car is"+car.upper())
# Out:
# My car isHONDA
# My car isTESLA
# My car isTATA

# %%
## Dict methods for accessing items..
person = {"name": "Alice", "age": 25, "city": "Mumbai"}
## name, age, city = Keys
# Alice, 25, Mumbai = Value

# ("name": "Alice") = single item..

# %%
type(person)
# Out:
# dict

# %%
## get all keys..
## to get all keys youll be using dict.keys() method..
keys = person.keys()

# %%
keys
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
keyss=list(keys)

# %%
keyss
# Out:
# ['name', 'age', 'city']

# %%
# iterate through keys..
for key in person.keys():
  #print(key)
  print(person.get(key))
# Out:
# Alice
# 25
# Mumbai

# %%
### To Get all values = values()

person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Mumbai'}

# %%
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Mumbai'}

# %%
values=person.values()

# %%
values
# Out:
# dict_values(['Alice', 25, 'Mumbai'])

# %%
values_list = list(person.values())

# %%
values
# Out:
# dict_values(['Alice', 25, 'Mumbai'])

# %%
## looping through dict values

for value in person.values():
  print(value)
# Out:
# Alice
# 25
# Mumbai

# %%
# Out:
# builtin_function_or_method

# %%
## Getting all key-avlue pair = items()

person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Mumbai'}

# %%
items=person.items()

# %%
item_list = list(items)

# %%
for item in item_list:
    print(item)
# Out:
# ('name', 'Alice')
# ('age', 25)
# ('city', 'Mumbai')

# %%
name,age,city=("lohith",28,"Banglore")

# %%
for key, value in person.items():
    print(f"this is the key:{key}")
    print(f"This is the value:{value}")
    print("")
    print("")
# Out:
# this is the key:name
# This is the value:Alice
#
#
# this is the key:age
# This is the value:25
#
#
# this is the key:city
# This is the value:Mumbai

# %%
nested_dict = {
    'name': 'Alice',
    'age': 25,
    "address": {
      'city': 'Mumbai',
      "pin": 40001
    }
}

# %%
city= nested_dict ['address']['city']

# %%
city
# Out:
# 'Mumbai'

# %%
nested_dict=["address"]["city"]
# Out:
# <>:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# C:\Users\Jahnavi\AppData\Local\Temp\ipykernel_5848\164207125.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   nested_dict=["address"]["city"]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 nested_dict=["address"]["city"]
#
# TypeError: list indices must be integers or slices, not str

# %%
## nested dict
students = {
    "student1": {
        "name": "Alice",
        "age": 25,
        "grade": "A"    # A+
    },
    "student2": {
        "name": "Bob",
        "age": 23,
        "grade": "B"
    },
    "student3": {
        "name": "Charlie",
        "age": 24,
        "grade": "A"
    }
}

# %%
## Access Alice's Age     # using get()
## Access Bob's Name
## safe acces with get() method
student_name=students.get("student1").get("name")
student_name
# Out:
# 'Alice'

# %%
## Merging dictionaris

dict1 = {"a":1, "b":2}
dict2 = {"c":3, "d":4}
dict3 = {"e":5, "f":6}
merged=dict1.copy()
merged
# Out:
# {'a': 1, 'b': 2}

# %%
merged.update(dict2)

# %%
merged
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
merged.update(dict3)

# %%
merged
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %%
merged_dict = dict1 | dict2 | dict3

# %%
merged_dict
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %% [markdown]
# ### Counting Occurenece..
#
# # count letter frequence in word
#
# word = "hello world"
#
# ## for, if, get()..
#
# # expected output = {'h': 1, 'e': 1, 'l': 3, 'o': 2, 'w': 1, 'r': 1, 'd': 1}

# %%
word="hello"
for words in word:
 print(word)
# Out:
# hello
# hello
# hello
# hello
# hello

# %%
word = "hello"

for wordss in word:
    if wordss == " ":
        continue
    
    count = 0
    for c in word:
        if wordss == c:
            count=count+ 1
    
    print(wordss, count)
# Out:
# h 1
# e 1
# l 2
# l 2
# o 1
