# %%
is_odd=lambda x:"odd" if x%2!=0 else "Not odd"

# %%
is_odd(25)
# Out:
# 'odd'

# %%
employees = [
    ("John", 50000, 5),   # (name, salary, experience)
    ("Alice", 70000, 3),
    ("Bob", 50000, 7)
]

# %%
#sort by salary,then experience
#filter high salary but low experience
salaryy=sorted(employees,key=lambda x:employees[0][1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 #sort by salary,then experience
#       2 #filter high salary but low experience
# ----> 3 salaryy=sorted(employees,key=lambda x:employees[0][1][2])
#
# Cell In[11], line 3, in <lambda>(x)
#       1 #sort by salary,then experience
#       2 #filter high salary but low experience
# ----> 3 salaryy=sorted(employees,key=lambda x:employees[0][1][2])
#
# TypeError: 'int' object is not subscriptable
