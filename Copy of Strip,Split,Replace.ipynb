# %%
tech_stack = "Azure DevOps and Python"

# %%
print(tech_stack)
# Out:
# Azure DevOps and Python

# %%
tech_stack[1]
# Out:
# 'z'

# %%
len(tech_stack)
# Out:
# 23

# %%
len("Janavi")
# Out:
# 6

# %%
print(type("janavi"))
# Out:
# <class 'str'>

# %%
print(type(123456))
# Out:
# <class 'int'>

# %%
print(type(23.78654))
# Out:
# <class 'float'>

# %%
"janavi".upper()
# Out:
# 'JANAVI'

# %%
tech_stack.upper()
# Out:
# 'AZURE DEVOPS AND PYTHON'

# %%
tech_stack.lower()
# Out:
# 'azure devops and python'

# %%
example="I Love Python"

# %%
print(f"converted to upper {example.upper()}")
# Out:
# converted to upper I LOVE PYTHON

# %%
print(f"Convert to LowerCase {example.lower()}")
# Out:
# Convert to LowerCase i love python

# %%
print(f"Original String is 'example'")
# Out:
# Original String is 'example'

# %%
print(f"Original String is {example}")
# Out:
# Original String is I Love Python

# %%
new_example=example.upper()

# %%
print(new_example)
# Out:
# I LOVE PYTHON

# %%
## removing leading and trainling whitespaces..
user_input = "    Data Science    "
print(user_input)
cleaned_input=user_input.strip()
print(cleaned_input)
# Out:
#     Data Science
# Data Science

# %%
## removing only leading whitespace
leading_space="   Janhavi"
print(leading_space)
remove_space=leading_space.lstrip()
print(remove_space)
# Out:
#    Janhavi
# Janhavi

# %%
# removing only trailing spaces
trailing_space = "Machine Learning   "
print(trailing_space)
remove_trailing_space=trailing_space.rstrip()
print(f"After trailing:{remove_trailing_space}")
# Out:
# Machine Learning
# After trailing:Machine Learning

# %%
# stripping specific chars
course_code = "****DS101************"
new_course_code=course_code.strip("*")
print(new_course_code)
# Out:
# DS101

# %%
## using lstrip with specific char
filename = "__init__.py"
new_filename=filename.rstrip("_")
print(new_filename)
# Out:
# __init__.py

# %%
## using rstrip with specific char
filenamee = "__init__"
new_filenamee=filenamee.rstrip("_")
print(new_filenamee)
# Out:
# __init

# %%
## using lstrip with specific char
filenamee = "__init__"
new_filenamee=filenamee.lstrip("_")
print(new_filenamee)
# Out:
# init__

# %%
## using rstrip with char

version = "v1.0.RELEASE...."
version.rstrip(".")
# Out:
# 'v1.0.RELEASE'

# %%
course_slogan = "Learn Data Engineering with Real-Time Projects"
tech_stack = "Azure DevOps and Python and SQL"

# %%
print(course_slogan)
print(tech_stack)
# Out:
# Learn Data Engineering with Real-Time Projects
# Azure DevOps and Python and SQL

# %%
## replace 'Data Engineering' with "Data science"
# str.replace('old', 'new')
print(course_slogan)
course_slogan.replace('Data Engineering',"Data science")
# Out:
# Learn Data Engineering with Real-Time Projects
# 'Learn Data science with Real-Time Projects'

# %%
## replacing all " " with "_"

slug = course_slogan.replace(" ", "_")
print(slug)
slug=course_slogan.replace(" ","*")
print(slug)
# Out:
# Learn_Data_Engineering_with_Real-Time_Projects
# Learn*Data*Engineering*with*Real-Time*Projects

# %%
## replace "and" with "&"
tech_stack.replace("and", "&").upper()
# adding methods one after another is called and chaining
# Out:
# 'AZURE DEVOPS & PYTHON & SQL'

# %%
## replaceing only 1 first occurence of 'and'
tech_stack.replace("and","&",1)
# Out:
# 'Azure DevOps & Python and SQL'

# %%
new_course_slogan = "Projects and and and and"
new_course_slogan.replace("and","$",2)
# Out:
# 'Projects $ $ and and'

# %%
course_slogan
# Out:
# 'Learn Data Engineering with Real-Time Projects'

# %%
# removing all the spaces form course_slogan
course_slogan.replace(" ","")
# Out:
# 'LearnDataEngineeringwithReal-TimeProjects'

# %%
# replace python with java
tech_stack.replace("Python","JAVA")
# Out:
# 'Azure DevOps and JAVA and SQL'

# %%
# replacingg multiple with chainging
filename = "project report final.docx"
filename.replace(" ","&").replace("docx","pdf")
# Out:
# 'project&report&final.pdf'

# %%
course_slogan = "Learn Data Engineering with Real-Time Projects"
tech_stack = "Azure DevOps,Python,SQL,Git"
institute = "Edukron"

# %%
## splitting slogan by whitespaces (default)
words = course_slogan.split()
print(words)
# Out:
# ['Learn', 'Data', 'Engineering', 'with', 'Real-Time', 'Projects']

# %%
len(words)
# Out:
# 6

# %%
type(words)
# Out:
# list

# %%
# splitting tech stakck by comma
tech_stack = "Azure DevOps,Python,SQL,Git"
skills = tech_stack.split(',')
print(skills)
# Out:
# ['Azure DevOps', 'Python', 'SQL', 'Git']

# %%
type(skills)
# Out:
# list

# %%
len(skills)
# Out:
# 4

# %%
# spliting institute name by char "k"

institute = "Edukron"
institute.split("k")
# Out:
# ['Edu', 'ron']

# %%
splitted = course_slogan.split(maxsplit=3)
splitted
# Out:
# ['Learn', 'Data', 'Engineering', 'with Real-Time Projects']

# %%
len(splitted)
# Out:
# 4

# %%
multi_space = "Azure.    DevOps  Python"
multi_space.split()
# Out:
# ['Azure.', 'DevOps', 'Python']

# %%
lst=['Azure.', 'DevOps', 'Python']

# %%
lst[0]="sql"

# %%
lst
# Out:
# ['sql', 'DevOps', 'Python']

# %%
lst[1]="java"
lst[2]="html"
lst
# Out:
# ['sql', 'java', 'html']

# %%
name="Janavi"
name="j" + name[1:]
print(name)
# Out:
# janavi

# %%
namee="Hema"
name=namee.replace("Hema","hema")
print(name)
# Out:
# hema

# %%
## String.join(iterable)
course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
tech_skills = ("Python", "SQL", "Git", "CI/CD")
words = ['Learn', 'Data', 'Engineering']

# %%
# 1. Joining course list with a comma and space
joined_courses = ", ".join(course_list)
print(f"1. Joined courses: '{joined_courses}'")
# Out:
# 1. Joined courses: 'Data Science, Data Engineering, Azure DevOps'

# %%
# 2. Joining tech skills with a hyphen
joined_skills = "-".join(tech_skills)
print(f"2. Joined skills: '{joined_skills}'")
# Out:
# 2. Joined skills: 'Python-SQL-Git-CI/CD'

# %%
# 3. Joining words back into a sentence with spaces
sentence = " ".join(words)
print(f"3. Rejoined sentence: '{sentence}'")
# Out:
# 3. Rejoined sentence: 'Learn Data Engineering'

# %%
# 4. Joining with an empty string (no separator)
institute = "Edukron"
char=list(institute)
print(char)
# Out:
# ['E', 'd', 'u', 'k', 'r', 'o', 'n']

# %%
# 5. Joining using a multi-character separator
separator=" | "
joined_fancy=separator.join(course_list)
print(joined_fancy)
# Out:
# Data Science | Data Engineering | Azure DevOps

# %%
# 6. Joining an iterable with only one element
single_item_list = ["Azure DevOps"]
result = ", ".join(single_item_list)
print(result)
# Out:
# Azure DevOps

# %%
# 7. Joining an empty iterable
empty_list = []
result = ", ".join(empty_list)
print(f"7. Joining empty list: '{result}'")
# Out:
# 7. Joining empty list: ''

# %%
## Combines multiple strings from a list into a single string using an underscore (_) as a separator.
items = ["Course", "Batch101", "Module5"]
identifier = "_".join(items)
print(f"8. Joining items with underscore: '{identifier}'")
# Out:
# 8. Joining items with underscore: 'Course_Batch101_Module5'

# %%
# 9. Joining using newline as separator
report_lines = ["Edukron Status Report", "Students: 1500", "Rating: 4.8"]
report = "\n".join(report_lines)
print(f"9. Joining with newline:\n{report}")
# Out:
# 9. Joining with newline:
# Edukron Status Report
# Students: 1500
# Rating: 4.8

# %%
mixed_list = ["Data Science", 101]

try:
    error_join = ", ".join(mixed_list)
except TypeError as e:
    print(f"10. Error joining list with non-string: {e}")
# Out:
# 10. Error joining list with non-string: sequence item 1: expected str instance, int found

# %%
mixed_listt = ["Data science", 102]

try:
    error_joinn = ",".join(mixed_listt)
except TypeError as msg:
    print(msg)
# Out:
# sequence item 1: expected str instance, int found

# %%
## str.startswith(prefix[, start[, end]]) and str.endswith(suffix[, start[, end]])

# %%
institute = "Edukron"
course_slogan = "Learn Data Engineering with Real-Time Projects"
filename = "edukron_report.pdf"

# %%
# 1. Check if institute starts with "Edu"
start_edu= institute.startswith("Edu")
print(f"Does institute starts with Edu ?{start_edu}")
# Out:
# Does institute starts with Edu ?True

# %%
# 2. Check if institute starts with "Data"
start_data= institute.startswith("Data")
print(f"Does institute starts with Date?{start_data}")
# Out:
# Does institute starts with Date?False

# %%
# 3. Check if slogan ends with "Projects"
ends_project=course_slogan.endswith("Projects")
print(f"Does course_slogon ends with Projects?{ends_project}")
# Out:
# Does course_slogon ends with Projects?True

# %%
# 4. Check if filename ends with ".pdf"
ends_pdf=filename.endswith("pdf")
print(f"Does {filename} ends with pdf?{ends_pdf}")
# Out:
# Does edukron_report.pdf ends with pdf?True

# %%
# 5. Check if filename ends with ".csv" or ".pdf"
ends_pdf_csv=filename.endswith((".csv",".pdf"))
print(f"Does file name ends with pdf or csv?{ends_pdf_csv}")
# Out:
# Does file name ends with pdf or csv?True

# %%
# 6. Check if slogan starts with "Learn" or "Explore"
starts_learn_explore = course_slogan.startswith(("Learn", "Explore"))
print(f"Does slogan starts with 'Learn' or 'Explore'{starts_learn_explore}")
# Out:
# Does slogan starts with 'Learn' or 'Explore'True

# %%
# 7. Check a slice: Does "Engineering" start at index 11 in slogan?
start_engineer=course_slogan.startswith("Engineering",11)
print(f"Does course_slogan starts with 'Engineering' at index 11?{start_engineer}")
# Out:
# Does course_slogan starts with 'Engineering' at index 11?True

# %%
##Check a slice: Does "Real-Time" end at index 36 in slogan?
# Slice [start:end] includes start, excludes end. So we check up to index 36.
